# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('iris.csv')
data
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
data.head(10)
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
# 5                 5.4                3.9                 1.7
# 6                 4.6                3.4                 1.4
# 7                 5.0                3.4                 1.5
# 8                 4.4                2.9                 1.4
# 9                 4.9                3.1                 1.5
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa
# 5                0.4  Iris-setosa
# 6                0.3  Iris-setosa
# ...

# %%
data.tail()
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica

# %%
data.describe()
# Out:
#        sepal length in cm  sepal width in cm  petal length in cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %%
data.columns
# Out:
# Index(['sepal length in cm', 'sepal width in cm', 'petal length in cm',
#        'petal width in cm', 'class'],
#       dtype='object')

# %%
data.dtypes
# Out:
# sepal length in cm    float64
# sepal width in cm     float64
# petal length in cm    float64
# petal width in cm     float64
# class                  object
# dtype: object

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# ...

# %%
data_updated = data.rename(columns = {'sepal length in cm':'sepal_length','petal length in cm':'petal_length','sepal width in cm':'sepal_width','petal width in cm':'petal_width','class':'species'})

# %%
print(data_updated)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x = data_updated["sepal_length"], y = data_updated["petal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x=data_updated["sepal_length"], y = data_updated["petal_length"])
plt.title("sepal length vs petal length")
# Out:
# Text(0.5, 1.0, 'sepal length vs petal length')

# %%
plt.plot(data_updated['sepal_width'])
plt.plot(data_updated['petal_width'])
plt.legend(["sepal_width", "petal_width"])

# %%
plt.plot(data_updated['sepal_width'])
plt.plot(data_updated['petal_width'])
plt.plot(data_updated['sepal_length'])
plt.plot(data_updated['petal_length'])
plt.legend(["sepal_width", "petal_width", "sepal_length", "petal_width"])
plt.rcParams["figure.figsize"] = (18,5)

# %%
sns.lmplot(x="sepal_length", y="sepal_width", data=data_updated, hue='species', legend=False)
plt.legend(["sepal_width", "sepal_length"])
# Out:
# C:\Users\vaish\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig,axes = plt.subplots(1,4, figsize=(20,5))
data_updated['sepal_length'].hist(ax=axes[0], color="r").set_title("sepal_length")
data_updated['petal_length'].hist(ax=axes[1], color="b").set_title("petal_length")
data_updated['sepal_width'].hist(ax=axes[2], color="g").set_title("sepal_width")
data_updated['petal_width'].hist(ax=axes[3], color="m").set_title("petal_width")
# Out:
# Text(0.5, 1.0, 'petal_width')

# %%
#Comparing the feature of each species type
fig, axes=plt.subplots(2,2, figsize=(16,5))
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=1)
sns.barplot(x=data_updated["species"], y=data_updated["sepal_length"], palette='cool', ax=axes[0][0]).set_title('species vs sepal_length')
sns.barplot(x=data_updated["species"], y=data_updated["sepal_width"], palette='cool', ax=axes[1][0]).set_title('species vs sepal_width')
sns.barplot(x=data_updated["species"], y=data_updated["petal_length"], palette='cool', ax=axes[0][1]).set_title('species vs petal_length')
sns.barplot(x=data_updated["species"], y=data_updated["petal_width"], palette='cool', ax=axes[1][1]).set_title('species vs petal_width')
# Out:
# Text(0.5, 1.0, 'species vs petal_width')

# %%
#Distribution of species in the dataset in %
data_updated['species'].value_counts().plot.pie(explode=[0.04,0.04,0.04], shadow=True, autopct='%1.2f%%', colors=["lightcoral","lightpink","lightblue"],).set_title("iris species classifications")
# Out:
# Text(0.5, 1.0, 'iris species classifications')

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data_updated['species']=label_encoder.fit_transform(data_updated['species'])
data_updated['species'].unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.model_selection import train_test_split
x=data_updated.drop(['species'], axis=1)
y=data_updated['species']

# %%
x_sepal_train, x_sepal_test, y_species_train, y_species_test=train_test_split(x,y, random_state=0,test_size=0.3)
x_sepal_train.shape, x_sepal_test.shape, y_species_train.shape, y_species_test.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %%
#Importing linear regression model from sklearn
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_sepal_train, y_species_train)
y_species_predicted=model.predict(x_sepal_test)

# %%
#Accuracy of linear regression model
from sklearn.metrics import accuracy_score
sc_lr=round(model.score(x_sepal_test, y_species_test)*100,2)
print("Accuracy: ",str(sc_lr),"%")
# Out:
# Accuracy:  89.99 %

# %%
#Logistic Regression for classification of IRIS species
from sklearn import linear_model
logistic_model=linear_model.LogisticRegression(max_iter=130)
logistic_model.fit(x_sepal_train, y_species_train)
# Out:
# LogisticRegression(max_iter=130)

# %%
y_species_logistic_predicted=logistic_model.predict(x_sepal_test)

# %%
sc_logr=round(logistic_model.score(x_sepal_test, y_species_test)*100,2)
print("Accuracy: ", str(sc_logr), "%")
# Out:
# Accuracy:  97.78 %

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_species_test, y_species_test)
cm
# Out:
# array([[16,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
sns.heatmap(cm, annot=True, cmap='BuPu_r')
plt.rcParams["figure.figsize"]=(10,2)
plt.xlabel('predicted value')
plt.ylabel('species')
# Out:
# Text(195.72222222222223, 0.5, 'species')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
knn_model=KNeighborsClassifier(n_neighbors=3)
knn_model.fit(x_sepal_train, y_species_train)
y_knn_pred=knn_model.predict(x_sepal_test)

# %%
accuracy=accuracy_score(y_species_test, y_knn_pred)*100
print('Accuracy of our model is equal '+str(round(accuracy, 2))+'%')
# Out:
# Accuracy of our model is equal 97.78%

# %%
from sklearn.metrics import classification_report
print(classification_report(y_species_test, y_knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
knn_cm=confusion_matrix(y_species_test, y_knn_pred)
knn_cm
# Out:
# array([[16,  0,  0],
#        [ 0, 17,  1],
#        [ 0,  0, 11]], dtype=int64)

# %%
sns.heatmap(knn_cm, annot=True, cmap='BuPu_r')
plt.rcParams["figure.figsize"]=(10,2)
plt.xlabel('predicted value')
plt.ylabel('species')
# Out:
# Text(95.72222222222221, 0.5, 'species')

# %%
scores_plt=[sc_lr, sc_logr, accuracy]
algorithms=["Linear Regression", "Logistic Regression", "KNN"]
sns.set(rc={'figure.figsize':(11,6)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms, scores_plt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 7
#       4 plt.xlabel("Algorithms")
#       5 plt.ylabel("Accuracy score")
# ----> 7 sns.barplot(algorithms, scores_plt)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
x_new=np.array([[3, 2, 1, 0.2], [ 4.9, 2.2, 3.8, 1.1], [ 5.3, 2.5, 4.6, 1.9]])
prediction=knn_model.predict(x_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: [0 1 2]
# C:\Users\vaish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
x_new=np.array([[4.6, 3.4, 1.4, 0.3]])
prediction=logistic_model.predict(x_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: [0]
# C:\Users\vaish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
